# %%
from skimage import io
from skimage.color import rgb2gray
import matplotlib.pyplot as plt 
import itk
from itkwidgets import view

# %%
im_collection = io.imread_collection('../dataset/3D MRI Image/cropped_resized_gray/*.png')
im_3d = im_collection.concatenate()
#grayscale = rgb2gray(im_collection)
print('done')
# Out:
# done

# %%
im_3d.shape
# Out:
# (68, 481, 579)

# %%
#%%


plt.imshow(im_3d[0])
plt.show()

plt.imshow(im_3d[10])
plt.show()

plt.imshow(im_3d[20])
plt.show()

plt.imshow(im_3d[30])
plt.show()

plt.imshow(im_3d[40])
plt.show()

plt.imshow(im_3d[50])
plt.show()

# %%
np_view = itk.image_view_from_array(im_3d)
plt.imshow(np_view[0])
plt.show()

# %%
view(np_view)
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, point_sets=[], rendered_image=<itk.itkImagePython.itkImageUC3; pr…

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager jupyter-leaflet
# Out:
# Building jupyterlab assets (production, minimized)
